# %% [markdown]
# # Assignment 8
# ## Due June 19th
# ### names:

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg as LA
from sklearn.datasets import make_classification
from sklearn.gaussian_process.kernels import RBF
from mpl_toolkits.mplot3d import Axes3D
import scipy.linalg


np.random.seed(42)

# %% [markdown]
# ## Exercise 1

# %%
def get_cicle_data(n=50, r=1):
    
    np.random.seed(n)
    
    thetas = np.random.uniform(0, 2*np.pi, n)
    data = np.array([r * np.sin(thetas), r * np.cos(thetas)]).T + np.random.normal(scale=1/8, size=(n,2))
    
    return data

# %%
def get_gaussian_data(n, mean=0.0, sigma=1.0):
    
    np.random.seed(n)
    
    data = np.random.normal(loc=mean, scale=sigma, size=(n,2))
    
    return data

# %% [markdown]
# ### a)

# %%
data, labels = make_classification(n_samples=25, n_features=2, n_informative=2, n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=1, random_state=42, class_sep=0)
data
data.shape[0]
# Out:
# 25

# %%
plt.scatter(data[:,0], data[:,1], c=labels)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data.mean(0)
# Out:
# array([ 0.04090563, -0.17039   ])

# %% [markdown]
# ### b)

# %%
def PCA(xs, l):
    
    x_average = xs.mean(0)
    #x_average = (np.sum(data[:,0])/ len(data), np.sum(data[:,1])/ len(data))
    # compute x_tilde = x_i - x_average
    x_tilde1 = []
    x_tilde2 = []
    for i in range (len(xs)):
        x_tilde1.append(xs[i,0] - x_average[0])
        x_tilde2.append(xs[i,1] - x_average[1])
    
    X = np.vstack((x_tilde1, x_tilde2)).T

    #plt.scatter(x_tilde[:,0], x_tilde[:,1], c=labels)
    #covariance matrix
    C = np.dot(X.T, X)
    #print(C.shape)
    #eigendecomposition -> ordered descending
    eigenvalues, eigenvectors = scipy.linalg.eigh(C)
    eigenvalues_desc = np.flip(eigenvalues, axis=0)
    #l largest eigenvectors
    V_l = eigenvectors[-l:]
    y_i = np.dot(V_l, X.T)
    P = np.dot(V_l.T, V_l)
    #print(np.dot(P, X.T).shape)
    z_i = np.dot(P, X.T).T + x_average
    
    return y_i, z_i, eigenvalues_desc, V_l

# %%
y_i, z_i, eigenvalues_desc, V_l = PCA(data, 1)
plt.figure()
plt.scatter(z_i[:,0], z_i[:,1], c=labels)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### c)

# %%
plt.figure()
#axis have equal length
plt.axis("equal")
plt.scatter(data[:,0], data[:,1], c= labels, marker = "o")
plt.scatter(z_i[:,0], z_i[:,1], c = labels, marker = "x")
for i in range(len(data)):
    plt.plot([z_i[i][0], data[i][0]], [z_i[i][1], data[i][1]])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### d)

# %%
a = get_cicle_data(25, 1)
b = get_cicle_data(25, 3)
data = np.concatenate([a,b])
labels = np.concatenate([np.zeros(a.shape[0]), np.ones(b.shape[0])])
plt.figure()
plt.scatter(data[:,0], data[:,1], c=labels)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y_i, z_i, eigenvalues_desc, V_l = PCA(data, 1)
plt.figure()
plt.scatter(z_i[:,0], z_i[:,1], c=labels)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
#axis have equal length
plt.axis("equal")
plt.scatter(data[:,0], data[:,1], c= labels, marker = "o")
plt.scatter(z_i[:,0], z_i[:,1], c = labels, marker = "x")
for i in range(len(data)):
    plt.plot([z_i[i][0], data[i][0]], [z_i[i][1], data[i][1]])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### e)

# %%
data, labels = make_classification(n_samples=25, n_features=2, n_informative=2, n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=1, random_state=42, class_sep=0)
data[:, 0] = 100 * data[:, 0] 
plt.figure()
plt.scatter(data[:,0], data[:,1], c=labels)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y_i, z_i, eigenvalues_desc, V_l = PCA(data, 1)
plt.figure()
plt.scatter(z_i[:,0], z_i[:,1], c=labels)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
#axis have equal length
plt.axis("equal")
plt.scatter(data[:,0], data[:,1], c= labels, marker = "o")
plt.scatter(z_i[:,0], z_i[:,1], c = labels, marker = "x")
for i in range(len(data)):
    plt.plot([z_i[i][0], data[i][0]], [z_i[i][1], data[i][1]])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Because the data set is not scaled, we can't visually see if the projection is orthonogal. We need to zoom in to further investigate the orthogonality. Per definition the projection has to be orthogonal so it has to be orthognal.

# %% [markdown]
# # Exercise 2)

# %%
data = np.concatenate([get_cicle_data(100, 2),
                       get_cicle_data(100, 4),
                       get_cicle_data(100, 6)])

labels = np.concatenate([np.zeros(100),
                         np.ones(100),
                         2 * np.ones(100)])

# %% [markdown]
# ### a)

# %%
fig = plt.figure()
color = ['orange' if l == 1 else 'red' if l == 2 else 'b' for l in labels]
plt.scatter(data[:, 0], data[:, 1], c=color)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### b)

# %%
def kernel_PCA(xs, kernel, l=2):
    n = len(kernel)
    one_n = [[1.0/n for i in range(n)] for j in range(n)]
    K_tilde = kernel - np.dot(one_n, kernel) - np.dot(kernel, one_n) + np.dot(np.dot(one_n, kernel), one_n)
    C = np.dot(K_tilde.T, K_tilde)
    eigenvalues, eigenvectors = scipy.linalg.eigh(C)
    eigenvalues, eigenvectors = eigenvalues.real, eigenvectors.real
    V_l = eigenvectors/np.sqrt(abs(eigenvalues))
    Y = []
    ys = 0
    
    for i in list(range(n)):
        for j in list(range(l)):
            ys = ys + np.dot(V_l[i, j], K_tilde[j, i])
        Y.append(ys)
        ys = 0
    return Y

# %% [markdown]
# ### c)

# %%
kernel = RBF(5.0)
K = kernel(data)

# %% [markdown]
# ### d)

# %%
Y = kernel_PCA(data, K, 3)
xs = Y[0]
ys = Y[1]
color = ['orange' if l == 1 else 'red' if l == 2 else 'b' for l in labels]

# %%
plt.figure()
plt.scatter(xs, ys, c=color)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# # a)

# %% [markdown]
# Taking $$ u = \begin{pmatrix} -1 \\ -1 \end{pmatrix}, v = \begin{pmatrix} 1 \\ 1 \end{pmatrix}\in \mathbb{R}^2, W = \begin {pmatrix} -1 & 1\end{pmatrix} \in \mathbb{R}^{1x2} $$
# $$Wu = 0$$
# $$Wv = 0$$
# $$Wu = Wv$$
# $$ u \neq v$$

# %% [markdown]
# An exact recovery is not possible because u and v are mapped to the same value. Therefore multiplying any of these values with U will also lead to the same value, eliminating the previously existing difference between u and v making exact recovery impossible.
# and therefore using U will also lead to the same recovered value.
